# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('marketing_customer_analysis.csv')

# %%
df.shape # 1 showing the amount of raws and columns accordingly
# Out:
# (10910, 26)

# %%
df.columns #2 having a look at the columns so I can see which one I must change for standartization
# Out:
# Index(['Unnamed: 0', 'Customer', 'State', 'Customer Lifetime Value',
#        'Response', 'Coverage', 'Education', 'Effective To Date',
#        'EmploymentStatus', 'Gender', 'Income', 'Location Code',
#        'Marital Status', 'Monthly Premium Auto', 'Months Since Last Claim',
#        'Months Since Policy Inception', 'Number of Open Complaints',
#        'Number of Policies', 'Policy Type', 'Policy', 'Renew Offer Type',
#        'Sales Channel', 'Total Claim Amount', 'Vehicle Class', 'Vehicle Size',
#        'Vehicle Type'],
#       dtype='object')

# %%
df1 = df.copy()

# %%
cols1 = [df1.columns[i].lower().replace(' ', '_') for i in range (len(df1.columns))]

# %%
df1.columns = cols1

# %%
df1.drop('unnamed:_0', inplace=True, axis = 1) # decided to delete the column because it wasn't useful anyways.

# %%
df1
# Out:
#       customer       state  customer_lifetime_value response  coverage  \
# 0      DK49336     Arizona              4809.216960       No     Basic
# 1      KX64629  California              2228.525238       No     Basic
# 2      LZ68649  Washington             14947.917300       No     Basic
# 3      XL78013      Oregon             22332.439460      Yes  Extended
# 4      QA50777      Oregon              9025.067525       No   Premium
# ...        ...         ...                      ...      ...       ...
# 10905  FE99816      Nevada             15563.369440       No   Premium
# 10906  KX53892      Oregon              5259.444853       No     Basic
# 10907  TL39050     Arizona             23893.304100       No  Extended
# 10908  WA60547  California             11971.977650       No   Premium
# 10909  IV32877         NaN              6857.519928      NaN     Basic
#
#       education effective_to_date employmentstatus gender  income  ...  \
# ...

# %%
df1.dtypes # object = string value and categorical, float and int are numerical
# Out:
# customer                          object
# state                             object
# customer_lifetime_value          float64
# response                          object
# coverage                          object
# education                         object
# effective_to_date                 object
# employmentstatus                  object
# gender                            object
# income                             int64
# location_code                     object
# marital_status                    object
# monthly_premium_auto               int64
# months_since_last_claim          float64
# months_since_policy_inception      int64
# number_of_open_complaints        float64
# number_of_policies                 int64
# policy_type                       object
# policy                            object
# renew_offer_type                  object
# sales_channel                     object
# total_claim_amount               float64
# vehicle_class                     object
# ...

# %%
df1.isna().sum()
# Out:
# customer                            0
# state                             631
# customer_lifetime_value             0
# response                          631
# coverage                            0
# education                           0
# effective_to_date                   0
# employmentstatus                    0
# gender                              0
# income                              0
# location_code                       0
# marital_status                      0
# monthly_premium_auto                0
# months_since_last_claim           633
# months_since_policy_inception       0
# number_of_open_complaints         633
# number_of_policies                  0
# policy_type                         0
# policy                              0
# renew_offer_type                    0
# sales_channel                       0
# total_claim_amount                  0
# vehicle_class                     622
# vehicle_size                      622
# vehicle_type                     5482
# ...

# %%
df2 = df1.copy()# there are too many null values in vehicle type, and I have a feeling that it is not that important, so I think best would be to drop the whole column.
df2.drop('vehicle_type', inplace=True, axis = 1)

# %%
df2
# Out:
#       customer       state  customer_lifetime_value response  coverage  \
# 0      DK49336     Arizona              4809.216960       No     Basic
# 1      KX64629  California              2228.525238       No     Basic
# 2      LZ68649  Washington             14947.917300       No     Basic
# 3      XL78013      Oregon             22332.439460      Yes  Extended
# 4      QA50777      Oregon              9025.067525       No   Premium
# ...        ...         ...                      ...      ...       ...
# 10905  FE99816      Nevada             15563.369440       No   Premium
# 10906  KX53892      Oregon              5259.444853       No     Basic
# 10907  TL39050     Arizona             23893.304100       No  Extended
# 10908  WA60547  California             11971.977650       No   Premium
# 10909  IV32877         NaN              6857.519928      NaN     Basic
#
#       education effective_to_date employmentstatus gender  income  ...  \
# ...

# %%
df2[df2['state'].isna()==True]
# Out:
#       customer state  customer_lifetime_value response  coverage  \
# 5      HO81102   NaN              4745.181764      NaN     Basic
# 11     GE63585   NaN              2420.711888      NaN     Basic
# 58     BR69566   NaN             14019.833140      NaN     Basic
# 62     UF44021   NaN              2108.493744      NaN     Basic
# 126    TE60343   NaN              4716.264294      NaN     Basic
# ...        ...   ...                      ...      ...       ...
# 10837  IJ40048   NaN              4978.950257      NaN     Basic
# 10849  SO38188   NaN              5308.617246      NaN  Extended
# 10874  PD52748   NaN             10036.536340      NaN  Extended
# 10894  EX63393   NaN              6314.492009      NaN  Extended
# 10909  IV32877   NaN              6857.519928      NaN     Basic
#
#                   education effective_to_date employmentstatus gender  income  \
# 5      High School or Below           2/14/11         Employed      M   50549
# ...

# %%
# state and response have a lot of nan's in common, I decided to delete it too.

# %%
df3 = df2.dropna(subset=["state"])
df3.isna().sum()
# Out:
# customer                           0
# state                              0
# customer_lifetime_value            0
# response                           0
# coverage                           0
# education                          0
# effective_to_date                  0
# employmentstatus                   0
# gender                             0
# income                             0
# location_code                      0
# marital_status                     0
# monthly_premium_auto               0
# months_since_last_claim          591
# months_since_policy_inception      0
# number_of_open_complaints        591
# number_of_policies                 0
# policy_type                        0
# policy                             0
# renew_offer_type                   0
# sales_channel                      0
# total_claim_amount                 0
# vehicle_class                    591
# vehicle_size                     591
# dtype: int64

# %%
df2[df2['vehicle_size'].isna()==True]
# Out:
#       customer       state  customer_lifetime_value response  coverage  \
# 87     ZH92587      Oregon              8126.766397       No     Basic
# 88     CJ51511     Arizona             13466.920710      Yes     Basic
# 89     ME37450     Arizona              5210.348372       No     Basic
# 97     CA22248      Oregon              2505.420430       No     Basic
# 148    HB24005  California              2347.048112       No     Basic
# ...        ...         ...                      ...      ...       ...
# 10852  KZ80424  Washington              8382.478392      Yes     Basic
# 10860  GA79817     Arizona              2369.111588       No     Basic
# 10879  FK95213  California             18611.453560       No  Extended
# 10883  FD64348      Oregon             22563.618380       No     Basic
# 10890  VQ78876      Oregon              4660.399573       No     Basic
#
#                   education effective_to_date employmentstatus gender  income  \
# ...

# %% [markdown]
# I see that the same raws have all 4 nan vallues present, instead of deleting them, I think would be better to add another category for 'vehicle_size' and type. And since 'number of complains' and 'month since last claim' have the same amount of nan, I am assuming that they had no complains and, therefore, no claims, so I will change the value of that cells to 0.

# %%
df3['vehicle_size'] = df3['vehicle_size'].fillna('Unspecified')
df3['vehicle_class'] = df3['vehicle_class'].fillna('Unspecified')
df3['number_of_open_complaints'] = df3['number_of_open_complaints'].fillna(0)
df3['months_since_last_claim'] = df3['months_since_last_claim'].fillna(0) 

# there was some massive error, but it worked i think
# Out:
# C:\Users\Dmitr\AppData\Local\Temp\ipykernel_12792\2927125085.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['vehicle_size'] = df3['vehicle_size'].fillna('Unspecified')
# C:\Users\Dmitr\AppData\Local\Temp\ipykernel_12792\2927125085.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['vehicle_class'] = df3['vehicle_class'].fillna('Unspecified')
# C:\Users\Dmitr\AppData\Local\Temp\ipykernel_12792\2927125085.py:3: SettingWithCopyWarning:
# ...

# %%
df3.isna().sum()
# Out:
# customer                         0
# state                            0
# customer_lifetime_value          0
# response                         0
# coverage                         0
# education                        0
# effective_to_date                0
# employmentstatus                 0
# gender                           0
# income                           0
# location_code                    0
# marital_status                   0
# monthly_premium_auto             0
# months_since_last_claim          0
# months_since_policy_inception    0
# number_of_open_complaints        0
# number_of_policies               0
# policy_type                      0
# policy                           0
# renew_offer_type                 0
# sales_channel                    0
# total_claim_amount               0
# vehicle_class                    0
# vehicle_size                     0
# vehicle_class                    0
# dtype: int64

# %%
df3['vehicle_size'].value_counts()
# Out:
# Medsize        6815
# Small          1861
# Large          1012
# Unspecified     591
# Name: vehicle_size, dtype: int64

# %%
import datetime

# %%
df3['effective_to_date'] = pd.to_datetime(df3['effective_to_date'])
# Out:
# C:\Users\Dmitr\AppData\Local\Temp\ipykernel_12792\1083546682.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['effective_to_date'] = pd.to_datetime(df3['effective_to_date'])

# %%
df3['effective_to_date']
# Out:
# 0       2011-02-18
# 1       2011-01-18
# 2       2011-02-10
# 3       2011-01-11
# 4       2011-01-17
#            ...
# 10904   2011-02-24
# 10905   2011-01-19
# 10906   2011-01-06
# 10907   2011-02-06
# 10908   2011-02-13
# Name: effective_to_date, Length: 10279, dtype: datetime64[ns]

# %%
df3['effective_to_date'].dt.month # hopefuly that's the right column im extracting it from...
# Out:
# 0        2
# 1        1
# 2        2
# 3        1
# 4        1
#         ..
# 10904    2
# 10905    1
# 10906    1
# 10907    2
# 10908    2
# Name: effective_to_date, Length: 10279, dtype: int64

# %%
df3['month'] = df3['effective_to_date'].dt.month

# %%
df3['month'].value_counts()
# Out:
# 1    5505
# 2    4774
# Name: month, dtype: int64

# %%
df3[df3['month'] <= 3] # we got all our rows like before because we only had month 1 and 2
# Out:
#       customer       state  customer_lifetime_value response  coverage  \
# 0      DK49336     Arizona              4809.216960       No     Basic
# 1      KX64629  California              2228.525238       No     Basic
# 2      LZ68649  Washington             14947.917300       No     Basic
# 3      XL78013      Oregon             22332.439460      Yes  Extended
# 4      QA50777      Oregon              9025.067525       No   Premium
# ...        ...         ...                      ...      ...       ...
# 10904  QI63521      Nevada             19228.463620       No     Basic
# 10905  FE99816      Nevada             15563.369440       No   Premium
# 10906  KX53892      Oregon              5259.444853       No     Basic
# 10907  TL39050     Arizona             23893.304100       No  Extended
# 10908  WA60547  California             11971.977650       No   Premium
#
#                   education effective_to_date employmentstatus gender  income  \
# ...
